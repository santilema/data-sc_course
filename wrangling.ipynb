# %% [markdown]
# <a href="https://colab.research.google.com/github/santilema/data-sc_course/blob/main/wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##Read and structure the data frames

# %%
p_df = pd.read_csv('p_data.csv', sep=';')
w_df = pd.read_csv('w_data.csv', sep=';')

# %%
p_df
# Out:
#         Age      Sex          ID                 Race         Country  \
# 0      39.0     Male       49084                White   United-States
# 1      50.0     Male       68553                White   United-States
# 2      38.0     Male      143654                White   United-States
# 3      53.0     Male       41510                Black   United-States
# 4      28.0   Female      195025                Black            Cuba
# ...     ...      ...         ...                  ...             ...
# 48837  33.0     Male   597186815                White   United-States
# 48838  39.0   Female   735617153                White   United-States
# 48839  64.0     Male  1131807446                Black   United-States
# 48840  38.0     Male   781422087                White   United-States
# 48841  44.0     Male   161771296   Asian-Pac-Islander   United-States
#
#         Education  Education-Num       Marital Status     Relationship
# ...

# %%
w_df
# Out:
#                Workclass    fnlwgt  Capital Gain  Capital Loss  \
# 0              State-gov   77516.0        2174.0           0.0
# 1       Self-emp-not-inc   83311.0           0.0           0.0
# 2                Private  215646.0           0.0           0.0
# 3                Private  234721.0           0.0           0.0
# 4                Private  338409.0           0.0           0.0
# ...                  ...       ...           ...           ...
# 48838            Private  215419.0           0.0           0.0
# 48839                  ?  321403.0           0.0           0.0
# 48840            Private  374983.0           0.0           0.0
# 48841            Private   83891.0        5455.0           0.0
# 48842       Self-emp-inc  182148.0           0.0           0.0
#
#        Hours per week          ID   Target
# 0                40.0       49084    <=50K
# 1                13.0       68553    <=50K
# 2                40.0      143654    <=50K
# ...

# %% [markdown]
# ##Merge both tables together

# %%
df = pd.merge(p_df, w_df, on="ID")

# %%
df
# Out:
#         Age      Sex          ID                 Race         Country  \
# 0      39.0     Male       49084                White   United-States
# 1      50.0     Male       68553                White   United-States
# 2      38.0     Male      143654                White   United-States
# 3      53.0     Male       41510                Black   United-States
# 4      28.0   Female      195025                Black            Cuba
# ...     ...      ...         ...                  ...             ...
# 48837  33.0     Male   597186815                White   United-States
# 48838  39.0   Female   735617153                White   United-States
# 48839  64.0     Male  1131807446                Black   United-States
# 48840  38.0     Male   781422087                White   United-States
# 48841  44.0     Male   161771296   Asian-Pac-Islander   United-States
#
#         Education  Education-Num       Marital Status     Relationship  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             48841 non-null  float64
#  1   Sex             48841 non-null  object
#  2   ID              48842 non-null  int64
#  3   Race            48841 non-null  object
#  4   Country         48841 non-null  object
#  5   Education       48841 non-null  object
#  6   Education-Num   48841 non-null  float64
#  7   Marital Status  48841 non-null  object
#  8   Relationship    48841 non-null  object
#  9   Workclass       48841 non-null  object
#  10  fnlwgt          48841 non-null  float64
#  11  Capital Gain    48841 non-null  float64
#  12  Capital Loss    48841 non-null  float64
#  13  Hours per week  48841 non-null  float64
#  14  Target          48841 non-null  object
# dtypes: float64(6), int64(1), object(8)
# memory usage: 6.0+ MB

# %% [markdown]
# ##1) Return the IDs which do not appear in both tables

# %%
diff = np.array(set(w_df.ID.values) - set(p_df.ID.values))
print('The IDs that are not repeated are', diff)
# Out:
# The IDs that are not repeated are {1344995623}

# %% [markdown]
# ##2) Correct target variables

# %%
df['ID'].groupby(df['Target']).count()
# Out:
# Target
#  <=50K     24720
#  <=50K.    12435
#  >50K       7841
#  >50K.      3845
# Name: ID, dtype: int64

# %%
df['Target'] = df['Target'].str.replace(".", "")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
df['ID'].groupby(df['Target']).count()
# Out:
# Target
#  <=50K    37155
#  >50K     11686
# Name: ID, dtype: int64

# %%
df['Target'] = df['Target'].str.strip()

# %%
df['ID'].groupby(df['Target']).count()
# Out:
# Target
# <=50K    37155
# >50K     11686
# Name: ID, dtype: int64

# %%
df.head()
# Out:
#     Age      Sex      ID    Race         Country   Education  Education-Num  \
# 0  39.0     Male   49084   White   United-States   Bachelors           13.0
# 1  50.0     Male   68553   White   United-States   Bachelors           13.0
# 2  38.0     Male  143654   White   United-States     HS-grad            9.0
# 3  53.0     Male   41510   Black   United-States        11th            7.0
# 4  28.0   Female  195025   Black            Cuba   Bachelors           13.0
#
#         Marital Status    Relationship          Workclass    fnlwgt  \
# 0        Never-married   Not-in-family          State-gov   77516.0
# 1   Married-civ-spouse         Husband   Self-emp-not-inc   83311.0
# 2             Divorced   Not-in-family            Private  215646.0
# 3   Married-civ-spouse         Husband            Private  234721.0
# 4   Married-civ-spouse            Wife            Private  338409.0
#
#    Capital Gain  Capital Loss  Hours per week Target
# ...

# %% [markdown]
# ##3) Calculate the following proportions

# %% [markdown]
# People with target ">50K" over total distinguished by "Race"

# %%
#Series with the differents ethnic groups and their total agregations
s1_race = df['ID'].groupby(df['Race']).count()

#Application of filter >50K
mas50 = df[df['Target'] == '>50K']
s2_race = mas50['ID'].groupby(mas50['Race']).count()

#Calculation of the proportion
race_per = s2_race.values/s1_race.values
race_proportion = pd.Series(data=race_per, index=s1_race.index)

# %%
race_proportion
# Out:
# Race
#  Amer-Indian-Eskimo    0.117021
#  Asian-Pac-Islander    0.269256
#  Black                 0.120811
#  Other                 0.123153
#  White                 0.253969
# dtype: float64

# %% [markdown]
# Proportion of people with target variable ">50K" over total differentiated by "Sex"

# %%
s1_sex = df['ID'].groupby(df['Sex']).count()

over50 = df[df['Target'] == '>50K']
s2_sex = mas50['ID'].groupby(mas50['Sex']).count()

sex_per = s2_sex.values/s1_sex.values
sex_proportion = pd.Series(data=sex_per, index=s1_sex.index)

# %%
sex_proportion
# Out:
# Sex
#  Female    0.109251
#  Male      0.303746
# dtype: float64

# %% [markdown]
# Proportion of people with target vatiable ">50K" over total discriminated by "Education"

# %%
s1_edu = df['ID'].groupby(df['Education']).count()

over50 = df[df['Target'] == '>50K']
s2_edu = over50['ID'].groupby(over50['Education']).count()

edu_per = s2_edu.values/s1_edu.values
edu_proportion = pd.Series(data=edu_per, index=s1_edu.index)

# %%
edu_proportion
# Out:
# Education
#  10th            0.062635
#  11th            0.050773
#  12th            0.073059
#  1st-4th         0.032389
#  5th-6th         0.053045
#  7th-8th         0.064921
#  9th             0.054233
#  Assoc-acdm      0.257964
#  Assoc-voc       0.253275
#  Bachelors       0.412762
#  Doctorate       0.725589
#  HS-grad         0.158578
#  Masters         0.549116
#  Preschool       0.012048
#  Prof-school     0.739808
#  Some-college    0.189649
# dtype: float64
